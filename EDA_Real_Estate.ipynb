# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
md = pd.read_csv('melb_data.csv',)
#df=df.drop(['id','date','lat','long'],axis=1)
md.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
md.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
# merapihkan data
md_MissVal = md.dropna()
md_MissVal.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
# Melihat distribusi data kolom Price dan Landsize
md_MissVal.hist(figsize=(14,14), xrot=0)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
# 
md_MissVal_describe = md_MissVal[['Price','Landsize']].describe()
md_MissVal_describe
# Out:
#               Price      Landsize
# count  6.196000e+03   6196.000000
# mean   1.068828e+06    471.006940
# std    6.751564e+05    897.449881
# min    1.310000e+05      0.000000
# 25%    6.200000e+05    152.000000
# 50%    8.800000e+05    373.000000
# 75%    1.325000e+06    628.000000
# max    9.000000e+06  37000.000000

# %%
# Menghitung Central Tendency menggunakan median(), 
# karena lebih cocok digunakan untuk distribusi miring
md_MissVal_CenTend = md_MissVal[['Price','Landsize']].median()
md_MissVal_CenTend
# Out:
# Price       880000.0
# Landsize       373.0
# dtype: float64

# %%
# Menggunakan perhitungan standar deviasi
md_MissVal_dispersion = md_MissVal[['Price','Landsize']].std()
md_MissVal_dispersion
# Out:
# Price       675156.427502
# Landsize       897.449881
# dtype: float64

# %%
# Menampilkan outlier menggunakan boxplot
sns.boxplot(x=md_MissVal['Distance'])
# Out:
# <AxesSubplot:xlabel='Distance'>

# %%
# melihat usia bangunan min(paling tua) dan max(paling muda)
md.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
# mengubah type data YearBuilt
md['YearBuilt'] = md['YearBuilt'].astype('category')
md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   category
#  16  CouncilArea    12211 non-null  object
# ...

# %%
# melihat data harga dan wilayah berdasarkan usia bangunan paling tua dan usia bangunan paling muda
md_YB = md.loc[(md['YearBuilt']==1196)|(md['YearBuilt']==2018),['YearBuilt','Price','Regionname']]
md_YB
# Out:
#      YearBuilt      Price             Regionname
# 1234    2018.0  1310000.0  Southern Metropolitan
# 9968    1196.0  1200000.0   Eastern Metropolitan

# %%
# menampilkan data sebaran data menggunakan plot
sns.scatterplot(data=md, x='YearBuilt', y='Price', hue='Regionname')
plt.style.use('seaborn')
plt.title('Sebaran Data Berdasarkan YearBuilt', size=15) 
plt.show()
